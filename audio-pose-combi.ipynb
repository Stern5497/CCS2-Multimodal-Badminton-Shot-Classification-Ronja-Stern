# %% [markdown]
# https://towardsdatascience.com/how-to-set-started-with-tensorflow-using-keras-api-and-google-colab-5421e5e4ef56
#
# intro tensorflow for colab
# https://medium.com/@oluyaled/audio-classification-using-deep-learning-and-tensorflow-a-step-by-step-guide-5327467ee9ab
#
# augmentation of audio data
# https://towardsdatascience.com/audio-deep-learning-made-simple-part-3-data-preparation-and-augmentation-24c6e1f6b52

# %%
# !pip install --quiet wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 29.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.3/277.3 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.5 MB/s eta 0:00:00

# %%
# import TensorFlow
import tensorflow as tf

#Check the version of TensorFlow you are using
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.15.0
# []

# %%
# load required libraries
import os
import librosa
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.image import resize
from tensorflow.keras.models import load_model
#import wandb

# %%
from google.colab import drive
import sys

#wandb.login()

drive.mount('/content/drive')
sys.path.append('/content/drive/MyDrive/ucph')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

def create_fit_model(X_train, y_train, X_val, y_val, index, model_name, target_shape):

  if model_name == 'pose':
    model = tf.keras.Sequential()

    # add input layer with the dimension of our data
    model.add(tf.keras.layers.InputLayer(input_shape=target_shape))

    # add first layer of 2D Conv followed by a batch norm
    model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())

    # add second layer of 2D Conv followed by a batch norm
    model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())

    model.add(tf.keras.layers.Dropout(0.25))

    # add third layer of 2D Conv followed by a batch norm
    model.add(tf.keras.layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())

    # add fourth layer of 2D Conv followed by a batch norm
    model.add(tf.keras.layers.Conv2D(filters=512, kernel_size=(3, 3), activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())

    # add fifth layer of 2D Conv followed by a batch norm
    model.add(tf.keras.layers.Conv2D(filters=1024, kernel_size=(3, 3), activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())

    model.add(tf.keras.layers.Dropout(0.25))

    # add global average pooling layer
    model.add(tf.keras.layers.GlobalAveragePooling2D())

    # add dense layer which activates network into 6 category output
    model.add(tf.keras.layers.Dense(units=3, activation=tf.nn.softmax))

  else:
    # initiate model
    model = tf.keras.Sequential()

    # add input layer with the dimension of our data
    model.add(tf.keras.layers.InputLayer(input_shape=target_shape))

    # add first layer of 1D Conv followed by a batch norm
    model.add(tf.keras.layers.Conv1D(filters=256, kernel_size=10))
    model.add(tf.keras.layers.BatchNormalization())

    # add Relu and Global average pooling layer
    model.add(tf.keras.layers.ReLU())
    model.add(tf.keras.layers.GlobalAveragePooling1D())

    # add dense layer which activates network into 6 category output
    model.add(tf.keras.layers.Dense(units=3, activation=tf.nn.softmax))

  # compile model with optimizer -> optimize learning rate
  model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])

  # Define the file path where the best model will be saved
  checkpoint_filepath = 'best_model.h5'

  # Define a ModelCheckpoint callback to save the best model during training
  model_checkpoint_callback = ModelCheckpoint(
      filepath=checkpoint_filepath,
      monitor='val_accuracy',  # Save the model based on validation accuracy
      save_best_only=True,
      mode='max',
      verbose=1
  )

  # fit our model indicating epoch and batch_size
  model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_val, y_val), callbacks=[model_checkpoint_callback])

  # After training, load the best model
  best_model = load_model(checkpoint_filepath)

  scores = best_model.evaluate(X_val, y_val,verbose=0)
  print(scores)

  # Save the model
  best_model.save(f'/content/drive/MyDrive/ucph/CCS2/models/{model_name}_classification_model_{index}.keras')

  return scores

# %%
from sklearn.model_selection import KFold

def train_model(model_name, target_shape, train_df, test_df):

  X_train, X_test, y_train, y_test = get_model_input_data(train_df, test_df, model_name)

  # Assuming X_train and y_train are your feature and target datasets
  kf = KFold(n_splits=10, shuffle=True, random_state=42)

  # Define lists to store training and validation indices
  train_indices_list = []
  val_indices_list = []

  # Generate the training and validation indices for each fold
  for train_indices, val_indices in kf.split(X_train):
      train_indices_list.append(train_indices)
      val_indices_list.append(val_indices)

  # define list to store scores (loss, accuracy, val_loss, val_arruracy)
  scores = []

  # use cross validation
  for fold in range(10):
      X_train_fold = X_train[train_indices_list[fold]]
      y_train_fold = y_train[train_indices_list[fold]]
      X_val_fold = X_train[val_indices_list[fold]]
      y_val_fold = y_train[val_indices_list[fold]]

      test_scores = create_fit_model(X_train_fold, y_train_fold, X_val_fold, y_val_fold, fold, model_name, target_shape)
      scores.append(test_scores)

  # find the best model among the 10 -> best val accuracy
  print(f"Model: {model_name}")
  for entry in scores:
    print(entry)

  # find max for val accuracy
  max_index = np.argmax(np.array(scores)[:, -1])
  print(f"Best model was found to be: {model_name}_classification_model_{max_index}")
  return f"{model_name}_classification_model_{max_index}"

# %%
def get_person(row):
  filename = row['filename']
  person = "_".split(filename)[1]
  return person

def convert_label(df):
  lab2id = {"clear": 0, "slice": 1, "smash": 2}
  # df['label'] = df['shot'].map(lab2id) this did not word as intended
  def map_label(shot):
        return lab2id.get(shot, -1)  # return -1 if shot is not in lab2id

  # Apply the map_label function to each element of the 'shot' column
  df['label'] = df['shot'].apply(map_label)
  return df

def add_mel_spectrogram(df):
  def create_mel_spectrogram(audio_array):
    audio_array = np.array(audio_array)
    mel_spectrogram = librosa.feature.melspectrogram(y=audio_array)
    return np.array(mel_spectrogram)

  df["audio"] = df["audio"].apply(create_mel_spectrogram)
  return df

def prepare_and_load_dataset():
  path = '/content/drive/MyDrive/ucph/CCS2/data/'
  column_names = ["filename", "shot", "pose", "audio", "mel_spectrogram", "start_point", "end_point"]
  # read csv and convert label
  train_df = pd.read_json(f'{path}train_0.json')
  test_df = pd.read_json(f'{path}test_0.json')

  for i in range(1, 10):
    data = pd.read_json(f'{path}train_{i}.json')
    train_df = pd.concat([train_df, data], ignore_index=True)
    data = pd.read_json(f'{path}test_{i}.json')
    test_df = pd.concat([test_df, data], ignore_index=True)

  # reset index
  train_df.reset_index(drop=True, inplace=True)
  test_df.reset_index(drop=True, inplace=True)

  # shuffle datasets
  train_df = train_df.sample(frac=1, random_state=42)
  test_df = test_df.sample(frac=1, random_state=42)

  # convert string lables to int
  train_df = convert_label(train_df)
  test_df = convert_label(test_df)

  # create mel_spectrograms
  train_df = add_mel_spectrogram(train_df)
  test_df = add_mel_spectrogram(test_df)

  # create pose arrays
  def create_pose_array(pose_array):
    try:
      pose_array = np.array(pose_array)
      if pose_array.shape == (62, 33, 4):
        # Calculate the mean and standard deviation over the second and third dimensions for each entry
        mean = np.mean(pose_array, axis=(0, 1))
        std = np.std(pose_array, axis=(0, 1))
        # Normalize the array
        pose_array = (pose_array - mean) / std
        return pose_array
      else:
        return np.nan
    except:
      return np.nan

  train_df['pose'] = train_df['pose'].apply(create_pose_array)
  train_df = train_df.dropna(subset=['pose'])

  test_df['pose'] = test_df['pose'].apply(create_pose_array)
  test_df = test_df.dropna(subset=['pose'])

  # create comb array
  def create_comb(row):
    pose_array = row['pose'].reshape(62, -1)
    mel_spec = np.array(row['audio'])
    if pose_array.shape == (62, 33, 4) and mel_spec.shape == (128, 176):
      pose = pose_array.resize(62, -1)
      zeros_array = np.zeros((128, 33*4))
      for i in range(62):
        zeros_array[(i*2)+1] = pose[i] # every second row for the pose part is empty
      combined = np.concatenate((zeros_array, mel_spec), axis=1)
      return combined

  train_df["comb"] = train_df.apply(create_comb, axis=1)
  test_df["comb"] = test_df.apply(create_comb, axis=1)

  return train_df, test_df

def get_model_input_data(train_df, test_df, column_name):
  # extract data and labels
  x_train = train_df[column_name].values
  x_train = np.stack(x_train)
  x_test = test_df[column_name].values
  x_test = np.stack(x_test)
  y_train = train_df["label"].values
  y_train_cat = to_categorical(y_train, num_classes=3)  # Convert labels to one-hot encoding
  y_test = test_df["label"].values
  return x_train, x_test, y_train_cat, y_test

# %%
from sklearn.metrics import f1_score, accuracy_score

# Define your class labels
classes = ['clear', 'slice', 'smash']

# Function to preprocess and classify one sample
def test_sample(sample, model):

    # Make predictions
    sample = sample.reshape(1, *sample.shape)
    predictions = model.predict(sample)

    # Get the class probabilities
    class_probabilities = predictions[0]

    # Get the predicted class index
    predicted_class_index = np.argmax(class_probabilities)
    return class_probabilities, predicted_class_index

# test the best model for audio, pose and comb for test data
def test_model(target_shape, model_file_name, X_test, y_test):

  # Load the saved model
  model = load_model(f'/content/drive/MyDrive/ucph/CCS2/models/{model_file_name}.keras')

  predictions = []
  predictions_per_class = []

  # Test an audio file
  for index in range(X_test.shape[0]):
    class_probabilities, predicted_class_index = test_sample(X_test[index], model)
    predictions.append(predicted_class_index)
    predictions_per_class.append(class_probabilities)

  y_test_cat = to_categorical(y_test, num_classes=3)  # Convert labels to one-hot encoding

  macro_f1 = f1_score(y_test, predictions, average='macro')

  # Calculate accuracy for each individual class
  class_accuracies = []
  for i in range(len(classes)):
      class_accuracy = accuracy_score(y_test == i, np.array(predictions) == i)
      class_accuracies.append(class_accuracy)

  # Calculate overall accuracy
  overall_accuracy = accuracy_score(y_test, predictions)

  # convert predictions to other data types
  predictions = np.array(predictions)
  predictions_per_class = np.stack(predictions_per_class)

  # calculate mean abs error
  mean_abs_error = np.sum(np.abs(np.where(y_test-predictions != 0, 1, 0))) / y_test.shape[0]

  # calculate rel error
  a = np.sum(np.multiply(y_test_cat, predictions_per_class), axis=1)
  b = np.where(y_test-predictions != 0, 1, 0)
  rel_error = np.sum(np.multiply(a, b))

  # print all the results
  print("-------------------------------------------------------------------------")
  print(f"{model_name} evaluation on test set")
  print(f"Macro F1 score: {macro_f1}")
  print("Accuracy for each individual class:")
  for i, accuracy in enumerate(class_accuracies):
      print(f"Class {classes[i]}: {accuracy}")
  print(f"Overall accuracy: {overall_accuracy}")
  print(f"Mean Absolute Error: {mean_abs_error}")
  print(f"Relative Error: {rel_error}")
  return predictions

# %%
train_df, test_df = prepare_and_load_dataset()
# Out:
# 550

# %%
best_models = {}

# train_df, test_df = prepare_and_load_dataset()

for model_name, target_shape in zip(['audio', 'pose', 'comb'], [(128, 176), (62, 33, 4), (128, 308)]):
  # for model_name, target_shape in zip(['pose'], [(62, 33, 4)]):
  model_file_name = train_model(model_name, target_shape, train_df, test_df)
  X_train, X_test, y_train, y_test = get_model_input_data(train_df, test_df, model_name)
  predictions = test_model(target_shape, model_file_name, X_test, y_test)
# Out:
# Epoch 1/20
# 16/16 [==============================] - ETA: 0s - loss: 0.6489 - accuracy: 0.7737
# Epoch 1: val_accuracy improved from -inf to 0.34545, saving model to best_model.h5
# 16/16 [==============================] - 7s 90ms/step - loss: 0.6489 - accuracy: 0.7737 - val_loss: 1.1330 - val_accuracy: 0.3455
# Epoch 2/20
# 11/16 [===================>..........] - ETA: 0s - loss: 0.4084 - accuracy: 0.8722
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 16/16 [==============================] - ETA: 0s - loss: 0.4216 - accuracy: 0.8566
# Epoch 2: val_accuracy improved from 0.34545 to 0.41818, saving model to best_model.h5
# 16/16 [==============================] - 0s 19ms/step - loss: 0.4216 - accuracy: 0.8566 - val_loss: 1.0114 - val_accuracy: 0.4182
# Epoch 3/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3707 - accuracy: 0.8918
# Epoch 3: val_accuracy improved from 0.41818 to 0.49091, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3642 - accuracy: 0.8929 - val_loss: 0.9055 - val_accuracy: 0.4909
# Epoch 4/20
#  9/16 [===============>..............] - ETA: 0s - loss: 0.3395 - accuracy: 0.8924
# Epoch 4: val_accuracy improved from 0.49091 to 0.72727, saving model to best_model.h5
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3170 - accuracy: 0.9030 - val_loss: 0.6293 - val_accuracy: 0.7273
# Epoch 5/20
#  9/16 [===============>..............] - ETA: 0s - loss: 0.2720 - accuracy: 0.9410
# Epoch 5: val_accuracy improved from 0.72727 to 0.76364, saving model to best_model.h5
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2749 - accuracy: 0.9333 - val_loss: 0.6074 - val_accuracy: 0.7636
# Epoch 6/20
#  9/16 [===============>..............] - ETA: 0s - loss: 0.2684 - accuracy: 0.8993
# Epoch 6: val_accuracy did not improve from 0.76364
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2752 - accuracy: 0.8970 - val_loss: 0.6414 - val_accuracy: 0.7091
# Epoch 7/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2297 - accuracy: 0.9333
# Epoch 7: val_accuracy improved from 0.76364 to 0.81818, saving model to best_model.h5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2297 - accuracy: 0.9333 - val_loss: 0.5111 - val_accuracy: 0.8182
# Epoch 8/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2146 - accuracy: 0.9354
# Epoch 8: val_accuracy improved from 0.81818 to 0.83636, saving model to best_model.h5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2146 - accuracy: 0.9354 - val_loss: 0.5356 - val_accuracy: 0.8364
# Epoch 9/20
#  9/16 [===============>..............] - ETA: 0s - loss: 0.2079 - accuracy: 0.9340
# Epoch 9: val_accuracy did not improve from 0.83636
# 16/16 [==============================] - 0s 10ms/step - loss: 0.2128 - accuracy: 0.9253 - val_loss: 0.5342 - val_accuracy: 0.8182
# Epoch 10/20
# 16/16 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9455
# Epoch 10: val_accuracy improved from 0.83636 to 0.85455, saving model to best_model.h5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1880 - accuracy: 0.9455 - val_loss: 0.4507 - val_accuracy: 0.8545
# Epoch 11/20
#  9/16 [===============>..............] - ETA: 0s - loss: 0.1946 - accuracy: 0.9444
# Epoch 11: val_accuracy improved from 0.85455 to 0.87273, saving model to best_model.h5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1862 - accuracy: 0.9515 - val_loss: 0.4555 - val_accuracy: 0.8727
# Epoch 12/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1739 - accuracy: 0.9495
# Epoch 12: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1727 - accuracy: 0.9495 - val_loss: 0.5842 - val_accuracy: 0.7636
# Epoch 13/20
#  9/16 [===============>..............] - ETA: 0s - loss: 0.1680 - accuracy: 0.9618
# Epoch 13: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1722 - accuracy: 0.9535 - val_loss: 0.5770 - val_accuracy: 0.8000
# Epoch 14/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1802 - accuracy: 0.9271
# Epoch 14: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1808 - accuracy: 0.9293 - val_loss: 0.4443 - val_accuracy: 0.8545
# Epoch 15/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1468 - accuracy: 0.9604
# Epoch 15: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1474 - accuracy: 0.9616 - val_loss: 0.4551 - val_accuracy: 0.8364
# Epoch 16/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1374 - accuracy: 0.9625
# Epoch 16: val_accuracy improved from 0.87273 to 0.89091, saving model to best_model.h5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1378 - accuracy: 0.9616 - val_loss: 0.4664 - val_accuracy: 0.8909
# Epoch 17/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1219 - accuracy: 0.9667
# Epoch 17: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1234 - accuracy: 0.9677 - val_loss: 0.4290 - val_accuracy: 0.8364
# Epoch 18/20
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1278 - accuracy: 0.9643
# Epoch 18: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1239 - accuracy: 0.9657 - val_loss: 0.4991 - val_accuracy: 0.8727
# Epoch 19/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1048 - accuracy: 0.9771
# Epoch 19: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1053 - accuracy: 0.9778 - val_loss: 0.4728 - val_accuracy: 0.8545
# Epoch 20/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1054 - accuracy: 0.9750
# Epoch 20: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1055 - accuracy: 0.9737 - val_loss: 0.4635 - val_accuracy: 0.8545
# [0.46642813086509705, 0.8909090757369995]
# Epoch 1/20
# 11/16 [===================>..........] - ETA: 0s - loss: 0.7095 - accuracy: 0.7131
# Epoch 1: val_accuracy improved from -inf to 0.54545, saving model to best_model.h5
# 16/16 [==============================] - 2s 28ms/step - loss: 0.6675 - accuracy: 0.7354 - val_loss: 0.8110 - val_accuracy: 0.5455
# Epoch 2/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4061 - accuracy: 0.8870
# Epoch 2: val_accuracy improved from 0.54545 to 0.56364, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4088 - accuracy: 0.8808 - val_loss: 0.7839 - val_accuracy: 0.5636
# Epoch 3/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.3422 - accuracy: 0.9010
# Epoch 3: val_accuracy improved from 0.56364 to 0.65455, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3306 - accuracy: 0.9091 - val_loss: 0.6616 - val_accuracy: 0.6545
# Epoch 4/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2855 - accuracy: 0.9327
# Epoch 4: val_accuracy improved from 0.65455 to 0.78182, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2950 - accuracy: 0.9232 - val_loss: 0.6288 - val_accuracy: 0.7818
# Epoch 5/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2739 - accuracy: 0.9255
# Epoch 5: val_accuracy improved from 0.78182 to 0.83636, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2802 - accuracy: 0.9212 - val_loss: 0.5832 - val_accuracy: 0.8364
# Epoch 6/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2346 - accuracy: 0.9351
# Epoch 6: val_accuracy did not improve from 0.83636
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2411 - accuracy: 0.9354 - val_loss: 0.5433 - val_accuracy: 0.7818
# Epoch 7/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2295 - accuracy: 0.9495
# Epoch 7: val_accuracy improved from 0.83636 to 0.85455, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2307 - accuracy: 0.9495 - val_loss: 0.5311 - val_accuracy: 0.8545
# Epoch 8/20
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1960 - accuracy: 0.9487
# Epoch 8: val_accuracy improved from 0.85455 to 0.87273, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1989 - accuracy: 0.9434 - val_loss: 0.5071 - val_accuracy: 0.8727
# Epoch 9/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1970 - accuracy: 0.9635
# Epoch 9: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1937 - accuracy: 0.9596 - val_loss: 0.4729 - val_accuracy: 0.8182
# Epoch 10/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1799 - accuracy: 0.9349
# Epoch 10: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1821 - accuracy: 0.9374 - val_loss: 0.4900 - val_accuracy: 0.8364
# Epoch 11/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1662 - accuracy: 0.9591
# Epoch 11: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1616 - accuracy: 0.9596 - val_loss: 0.4630 - val_accuracy: 0.8727
# Epoch 12/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1422 - accuracy: 0.9688
# Epoch 12: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1510 - accuracy: 0.9616 - val_loss: 0.4169 - val_accuracy: 0.8364
# Epoch 13/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1417 - accuracy: 0.9639
# Epoch 13: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1455 - accuracy: 0.9636 - val_loss: 0.5091 - val_accuracy: 0.8364
# Epoch 14/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1488 - accuracy: 0.9635
# Epoch 14: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1379 - accuracy: 0.9677 - val_loss: 0.4399 - val_accuracy: 0.8727
# Epoch 15/20
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1447 - accuracy: 0.9621
# Epoch 15: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1423 - accuracy: 0.9636 - val_loss: 0.6006 - val_accuracy: 0.8364
# Epoch 16/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1530 - accuracy: 0.9453
# Epoch 16: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1457 - accuracy: 0.9556 - val_loss: 0.6361 - val_accuracy: 0.7818
# Epoch 17/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1211 - accuracy: 0.9808
# Epoch 17: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1193 - accuracy: 0.9758 - val_loss: 0.4466 - val_accuracy: 0.8727
# Epoch 18/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1076 - accuracy: 0.9832
# Epoch 18: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1094 - accuracy: 0.9778 - val_loss: 0.5054 - val_accuracy: 0.8727
# Epoch 19/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0903 - accuracy: 0.9784
# Epoch 19: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1016 - accuracy: 0.9737 - val_loss: 0.4812 - val_accuracy: 0.8545
# Epoch 20/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0981 - accuracy: 0.9750
# Epoch 20: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0975 - accuracy: 0.9758 - val_loss: 0.3926 - val_accuracy: 0.8727
# [0.5071407556533813, 0.8727272748947144]
# Epoch 1/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6646 - accuracy: 0.7452
# Epoch 1: val_accuracy improved from -inf to 0.54545, saving model to best_model.h5
# 16/16 [==============================] - 2s 38ms/step - loss: 0.6548 - accuracy: 0.7535 - val_loss: 0.8450 - val_accuracy: 0.5455
# Epoch 2/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4524 - accuracy: 0.8413
# Epoch 2: val_accuracy did not improve from 0.54545
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4493 - accuracy: 0.8404 - val_loss: 0.7982 - val_accuracy: 0.5091
# Epoch 3/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3531 - accuracy: 0.8942
# Epoch 3: val_accuracy improved from 0.54545 to 0.72727, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3620 - accuracy: 0.8869 - val_loss: 0.6199 - val_accuracy: 0.7273
# Epoch 4/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3157 - accuracy: 0.9087
# Epoch 4: val_accuracy improved from 0.72727 to 0.76364, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3125 - accuracy: 0.9091 - val_loss: 0.5248 - val_accuracy: 0.7636
# Epoch 5/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.2903 - accuracy: 0.9219
# Epoch 5: val_accuracy improved from 0.76364 to 0.83636, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2888 - accuracy: 0.9232 - val_loss: 0.4106 - val_accuracy: 0.8364
# Epoch 6/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2494 - accuracy: 0.9351
# Epoch 6: val_accuracy improved from 0.83636 to 0.85455, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2558 - accuracy: 0.9273 - val_loss: 0.3658 - val_accuracy: 0.8545
# Epoch 7/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2435 - accuracy: 0.9303
# Epoch 7: val_accuracy did not improve from 0.85455
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2457 - accuracy: 0.9232 - val_loss: 0.3416 - val_accuracy: 0.8545
# Epoch 8/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2127 - accuracy: 0.9351
# Epoch 8: val_accuracy improved from 0.85455 to 0.92727, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2119 - accuracy: 0.9333 - val_loss: 0.2663 - val_accuracy: 0.9273
# Epoch 9/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.2218 - accuracy: 0.9453
# Epoch 9: val_accuracy improved from 0.92727 to 0.96364, saving model to best_model.h5
# 16/16 [==============================] - 0s 16ms/step - loss: 0.2163 - accuracy: 0.9414 - val_loss: 0.2339 - val_accuracy: 0.9636
# Epoch 10/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1781 - accuracy: 0.9519
# Epoch 10: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1882 - accuracy: 0.9475 - val_loss: 0.2263 - val_accuracy: 0.9455
# Epoch 11/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1982 - accuracy: 0.9447
# Epoch 11: val_accuracy improved from 0.96364 to 0.98182, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1962 - accuracy: 0.9495 - val_loss: 0.2072 - val_accuracy: 0.9818
# Epoch 12/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1693 - accuracy: 0.9471
# Epoch 12: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1702 - accuracy: 0.9475 - val_loss: 0.2700 - val_accuracy: 0.8545
# Epoch 13/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1688 - accuracy: 0.9519
# Epoch 13: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1782 - accuracy: 0.9394 - val_loss: 0.2019 - val_accuracy: 0.9273
# Epoch 14/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1526 - accuracy: 0.9591
# Epoch 14: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1533 - accuracy: 0.9576 - val_loss: 0.1588 - val_accuracy: 0.9636
# Epoch 15/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1418 - accuracy: 0.9567
# Epoch 15: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1418 - accuracy: 0.9576 - val_loss: 0.1418 - val_accuracy: 0.9818
# Epoch 16/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1377 - accuracy: 0.9663
# Epoch 16: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1355 - accuracy: 0.9657 - val_loss: 0.1802 - val_accuracy: 0.9455
# Epoch 17/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1331 - accuracy: 0.9639
# Epoch 17: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1372 - accuracy: 0.9636 - val_loss: 0.1810 - val_accuracy: 0.9091
# Epoch 18/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1534 - accuracy: 0.9583
# Epoch 18: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1459 - accuracy: 0.9616 - val_loss: 0.1292 - val_accuracy: 0.9818
# Epoch 19/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1236 - accuracy: 0.9639
# Epoch 19: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1220 - accuracy: 0.9636 - val_loss: 0.1339 - val_accuracy: 0.9818
# Epoch 20/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1161 - accuracy: 0.9736
# Epoch 20: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1171 - accuracy: 0.9717 - val_loss: 0.1389 - val_accuracy: 0.9455
# [0.20722293853759766, 0.9818181991577148]
# Epoch 1/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6351 - accuracy: 0.7716
# Epoch 1: val_accuracy improved from -inf to 0.47273, saving model to best_model.h5
# 16/16 [==============================] - 2s 28ms/step - loss: 0.6152 - accuracy: 0.7818 - val_loss: 0.8930 - val_accuracy: 0.4727
# Epoch 2/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.4137 - accuracy: 0.8750
# Epoch 2: val_accuracy improved from 0.47273 to 0.50909, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.4113 - accuracy: 0.8747 - val_loss: 0.9112 - val_accuracy: 0.5091
# Epoch 3/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3439 - accuracy: 0.8966
# Epoch 3: val_accuracy improved from 0.50909 to 0.60000, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3427 - accuracy: 0.8990 - val_loss: 0.7922 - val_accuracy: 0.6000
# Epoch 4/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3090 - accuracy: 0.9087
# Epoch 4: val_accuracy improved from 0.60000 to 0.61818, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3099 - accuracy: 0.9091 - val_loss: 0.6271 - val_accuracy: 0.6182
# Epoch 5/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2749 - accuracy: 0.9231
# Epoch 5: val_accuracy improved from 0.61818 to 0.72727, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2748 - accuracy: 0.9232 - val_loss: 0.5275 - val_accuracy: 0.7273
# Epoch 6/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.2681 - accuracy: 0.9401
# Epoch 6: val_accuracy did not improve from 0.72727
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2651 - accuracy: 0.9333 - val_loss: 0.6073 - val_accuracy: 0.6727
# Epoch 7/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2319 - accuracy: 0.9303
# Epoch 7: val_accuracy did not improve from 0.72727
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2448 - accuracy: 0.9232 - val_loss: 0.5250 - val_accuracy: 0.7273
# Epoch 8/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2158 - accuracy: 0.9447
# Epoch 8: val_accuracy improved from 0.72727 to 0.87273, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2158 - accuracy: 0.9434 - val_loss: 0.4379 - val_accuracy: 0.8727
# Epoch 9/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2195 - accuracy: 0.9255
# Epoch 9: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2045 - accuracy: 0.9354 - val_loss: 0.4257 - val_accuracy: 0.8727
# Epoch 10/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2023 - accuracy: 0.9447
# Epoch 10: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1981 - accuracy: 0.9475 - val_loss: 0.4272 - val_accuracy: 0.8182
# Epoch 11/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1624 - accuracy: 0.9583
# Epoch 11: val_accuracy improved from 0.87273 to 0.89091, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1762 - accuracy: 0.9535 - val_loss: 0.4044 - val_accuracy: 0.8909
# Epoch 12/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1857 - accuracy: 0.9567
# Epoch 12: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1757 - accuracy: 0.9576 - val_loss: 0.3522 - val_accuracy: 0.8545
# Epoch 13/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1821 - accuracy: 0.9423
# Epoch 13: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1812 - accuracy: 0.9394 - val_loss: 0.3731 - val_accuracy: 0.8909
# Epoch 14/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1694 - accuracy: 0.9495
# Epoch 14: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1678 - accuracy: 0.9475 - val_loss: 0.5630 - val_accuracy: 0.8727
# Epoch 15/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1628 - accuracy: 0.9531
# Epoch 15: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1615 - accuracy: 0.9576 - val_loss: 0.3185 - val_accuracy: 0.8727
# Epoch 16/20
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1487 - accuracy: 0.9576
# Epoch 16: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1489 - accuracy: 0.9576 - val_loss: 0.3721 - val_accuracy: 0.8727
# Epoch 17/20
# 16/16 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9596
# Epoch 17: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1403 - accuracy: 0.9596 - val_loss: 0.4447 - val_accuracy: 0.8364
# Epoch 18/20
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1348 - accuracy: 0.9576
# Epoch 18: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1314 - accuracy: 0.9616 - val_loss: 0.4044 - val_accuracy: 0.8909
# Epoch 19/20
# 11/16 [===================>..........] - ETA: 0s - loss: 0.1423 - accuracy: 0.9545
# Epoch 19: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1363 - accuracy: 0.9556 - val_loss: 0.3723 - val_accuracy: 0.8909
# Epoch 20/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1125 - accuracy: 0.9750
# Epoch 20: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1109 - accuracy: 0.9758 - val_loss: 0.3788 - val_accuracy: 0.8727
# [0.40438804030418396, 0.8909090757369995]
# Epoch 1/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.7133 - accuracy: 0.7163
# Epoch 1: val_accuracy improved from -inf to 0.34545, saving model to best_model.h5
# 16/16 [==============================] - 2s 27ms/step - loss: 0.6884 - accuracy: 0.7313 - val_loss: 1.0340 - val_accuracy: 0.3455
# Epoch 2/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4503 - accuracy: 0.8438
# Epoch 2: val_accuracy improved from 0.34545 to 0.40000, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4559 - accuracy: 0.8444 - val_loss: 0.9726 - val_accuracy: 0.4000
# Epoch 3/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3669 - accuracy: 0.8846
# Epoch 3: val_accuracy improved from 0.40000 to 0.49091, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3706 - accuracy: 0.8828 - val_loss: 0.8353 - val_accuracy: 0.4909
# Epoch 4/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3506 - accuracy: 0.8894
# Epoch 4: val_accuracy improved from 0.49091 to 0.65455, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.3438 - accuracy: 0.8909 - val_loss: 0.5992 - val_accuracy: 0.6545
# Epoch 5/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.2679 - accuracy: 0.9375
# Epoch 5: val_accuracy did not improve from 0.65455
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2924 - accuracy: 0.9152 - val_loss: 0.7186 - val_accuracy: 0.6000
# Epoch 6/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2688 - accuracy: 0.9087
# Epoch 6: val_accuracy improved from 0.65455 to 0.87273, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2672 - accuracy: 0.9051 - val_loss: 0.4130 - val_accuracy: 0.8727
# Epoch 7/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2503 - accuracy: 0.9255
# Epoch 7: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2469 - accuracy: 0.9273 - val_loss: 0.4383 - val_accuracy: 0.7818
# Epoch 8/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.2259 - accuracy: 0.9323
# Epoch 8: val_accuracy improved from 0.87273 to 0.94545, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2224 - accuracy: 0.9354 - val_loss: 0.3263 - val_accuracy: 0.9455
# Epoch 9/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2192 - accuracy: 0.9327
# Epoch 9: val_accuracy did not improve from 0.94545
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2255 - accuracy: 0.9232 - val_loss: 0.3191 - val_accuracy: 0.9455
# Epoch 10/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2119 - accuracy: 0.9351
# Epoch 10: val_accuracy did not improve from 0.94545
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2121 - accuracy: 0.9333 - val_loss: 0.3719 - val_accuracy: 0.8545
# Epoch 11/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2005 - accuracy: 0.9423
# Epoch 11: val_accuracy did not improve from 0.94545
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1912 - accuracy: 0.9434 - val_loss: 0.2731 - val_accuracy: 0.9273
# Epoch 12/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1666 - accuracy: 0.9543
# Epoch 12: val_accuracy improved from 0.94545 to 0.98182, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1820 - accuracy: 0.9455 - val_loss: 0.2251 - val_accuracy: 0.9818
# Epoch 13/20
# 11/16 [===================>..........] - ETA: 0s - loss: 0.1633 - accuracy: 0.9545
# Epoch 13: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1728 - accuracy: 0.9495 - val_loss: 0.2099 - val_accuracy: 0.9636
# Epoch 14/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1662 - accuracy: 0.9663
# Epoch 14: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1689 - accuracy: 0.9636 - val_loss: 0.2124 - val_accuracy: 0.9455
# Epoch 15/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1672 - accuracy: 0.9423
# Epoch 15: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1676 - accuracy: 0.9434 - val_loss: 0.1985 - val_accuracy: 0.9273
# Epoch 16/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1522 - accuracy: 0.9557
# Epoch 16: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1588 - accuracy: 0.9596 - val_loss: 0.1856 - val_accuracy: 0.9636
# Epoch 17/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1489 - accuracy: 0.9495
# Epoch 17: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1518 - accuracy: 0.9495 - val_loss: 0.2262 - val_accuracy: 0.9273
# Epoch 18/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.1546 - accuracy: 0.9505
# Epoch 18: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1446 - accuracy: 0.9576 - val_loss: 0.1624 - val_accuracy: 0.9455
# Epoch 19/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1223 - accuracy: 0.9760
# Epoch 19: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1204 - accuracy: 0.9758 - val_loss: 0.1974 - val_accuracy: 0.9273
# Epoch 20/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1267 - accuracy: 0.9615
# Epoch 20: val_accuracy did not improve from 0.98182
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1291 - accuracy: 0.9616 - val_loss: 0.2547 - val_accuracy: 0.9273
# [0.22505715489387512, 0.9818181991577148]
# Epoch 1/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.7248 - accuracy: 0.6731
# Epoch 1: val_accuracy improved from -inf to 0.34545, saving model to best_model.h5
# 16/16 [==============================] - 2s 29ms/step - loss: 0.7188 - accuracy: 0.6869 - val_loss: 1.0082 - val_accuracy: 0.3455
# Epoch 2/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4584 - accuracy: 0.8630
# Epoch 2: val_accuracy did not improve from 0.34545
# 16/16 [==============================] - 0s 12ms/step - loss: 0.4474 - accuracy: 0.8687 - val_loss: 1.0413 - val_accuracy: 0.3455
# Epoch 3/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3870 - accuracy: 0.8774
# Epoch 3: val_accuracy improved from 0.34545 to 0.47273, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.3820 - accuracy: 0.8808 - val_loss: 0.7959 - val_accuracy: 0.4727
# Epoch 4/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3461 - accuracy: 0.9062
# Epoch 4: val_accuracy improved from 0.47273 to 0.58182, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.3444 - accuracy: 0.9071 - val_loss: 0.8102 - val_accuracy: 0.5818
# Epoch 5/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.3101 - accuracy: 0.8958
# Epoch 5: val_accuracy improved from 0.58182 to 0.74545, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.3165 - accuracy: 0.8990 - val_loss: 0.5610 - val_accuracy: 0.7455
# Epoch 6/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.2842 - accuracy: 0.9115
# Epoch 6: val_accuracy improved from 0.74545 to 0.80000, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2768 - accuracy: 0.9152 - val_loss: 0.4958 - val_accuracy: 0.8000
# Epoch 7/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2718 - accuracy: 0.9087
# Epoch 7: val_accuracy did not improve from 0.80000
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2633 - accuracy: 0.9172 - val_loss: 0.5562 - val_accuracy: 0.7273
# Epoch 8/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2593 - accuracy: 0.9255
# Epoch 8: val_accuracy improved from 0.80000 to 0.83636, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2561 - accuracy: 0.9232 - val_loss: 0.4570 - val_accuracy: 0.8364
# Epoch 9/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9394
# Epoch 9: val_accuracy improved from 0.83636 to 0.90909, saving model to best_model.h5
# 16/16 [==============================] - 0s 18ms/step - loss: 0.2165 - accuracy: 0.9394 - val_loss: 0.3613 - val_accuracy: 0.9091
# Epoch 10/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.2216 - accuracy: 0.9375
# Epoch 10: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 17ms/step - loss: 0.2130 - accuracy: 0.9455 - val_loss: 0.3886 - val_accuracy: 0.9091
# Epoch 11/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2115 - accuracy: 0.9333
# Epoch 11: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 16ms/step - loss: 0.2107 - accuracy: 0.9333 - val_loss: 0.4265 - val_accuracy: 0.8727
# Epoch 12/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1850 - accuracy: 0.9479
# Epoch 12: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1833 - accuracy: 0.9495 - val_loss: 0.3323 - val_accuracy: 0.8909
# Epoch 13/20
# 11/16 [===================>..........] - ETA: 0s - loss: 0.1607 - accuracy: 0.9574
# Epoch 13: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1773 - accuracy: 0.9556 - val_loss: 0.3046 - val_accuracy: 0.9091
# Epoch 14/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1756 - accuracy: 0.9396
# Epoch 14: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1733 - accuracy: 0.9414 - val_loss: 0.3612 - val_accuracy: 0.8545
# Epoch 15/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1587 - accuracy: 0.9563
# Epoch 15: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1568 - accuracy: 0.9576 - val_loss: 0.2943 - val_accuracy: 0.8909
# Epoch 16/20
# 16/16 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9636
# Epoch 16: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1485 - accuracy: 0.9636 - val_loss: 0.3433 - val_accuracy: 0.8727
# Epoch 17/20
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1269 - accuracy: 0.9732
# Epoch 17: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1286 - accuracy: 0.9717 - val_loss: 0.2825 - val_accuracy: 0.8909
# Epoch 18/20
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1480 - accuracy: 0.9554
# Epoch 18: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1572 - accuracy: 0.9475 - val_loss: 0.4358 - val_accuracy: 0.7636
# Epoch 19/20
# 16/16 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9556
# Epoch 19: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1550 - accuracy: 0.9556 - val_loss: 0.4071 - val_accuracy: 0.8000
# Epoch 20/20
# 11/16 [===================>..........] - ETA: 0s - loss: 0.1368 - accuracy: 0.9574
# Epoch 20: val_accuracy improved from 0.90909 to 0.94545, saving model to best_model.h5
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1427 - accuracy: 0.9576 - val_loss: 0.2182 - val_accuracy: 0.9455
# [0.21822774410247803, 0.9454545378684998]
# Epoch 1/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6818 - accuracy: 0.7043
# Epoch 1: val_accuracy improved from -inf to 0.32727, saving model to best_model.h5
# 16/16 [==============================] - 2s 27ms/step - loss: 0.6558 - accuracy: 0.7192 - val_loss: 1.2846 - val_accuracy: 0.3273
# Epoch 2/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4374 - accuracy: 0.8678
# Epoch 2: val_accuracy improved from 0.32727 to 0.34545, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4297 - accuracy: 0.8727 - val_loss: 1.0838 - val_accuracy: 0.3455
# Epoch 3/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3565 - accuracy: 0.8798
# Epoch 3: val_accuracy improved from 0.34545 to 0.54545, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.3547 - accuracy: 0.8848 - val_loss: 0.8006 - val_accuracy: 0.5455
# Epoch 4/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3148 - accuracy: 0.8966
# Epoch 4: val_accuracy improved from 0.54545 to 0.61818, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.3240 - accuracy: 0.8889 - val_loss: 0.6859 - val_accuracy: 0.6182
# Epoch 5/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2840 - accuracy: 0.9135
# Epoch 5: val_accuracy improved from 0.61818 to 0.83636, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2816 - accuracy: 0.9212 - val_loss: 0.4967 - val_accuracy: 0.8364
# Epoch 6/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2741 - accuracy: 0.9207
# Epoch 6: val_accuracy improved from 0.83636 to 0.87273, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2732 - accuracy: 0.9152 - val_loss: 0.4218 - val_accuracy: 0.8727
# Epoch 7/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2549 - accuracy: 0.9062
# Epoch 7: val_accuracy improved from 0.87273 to 0.96364, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2476 - accuracy: 0.9131 - val_loss: 0.3569 - val_accuracy: 0.9636
# Epoch 8/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2372 - accuracy: 0.9303
# Epoch 8: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2352 - accuracy: 0.9333 - val_loss: 0.4158 - val_accuracy: 0.8727
# Epoch 9/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.2259 - accuracy: 0.9207
# Epoch 9: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2264 - accuracy: 0.9253 - val_loss: 0.3221 - val_accuracy: 0.9091
# Epoch 10/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1972 - accuracy: 0.9423
# Epoch 10: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1877 - accuracy: 0.9475 - val_loss: 0.3486 - val_accuracy: 0.8909
# Epoch 11/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1973 - accuracy: 0.9375
# Epoch 11: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1950 - accuracy: 0.9394 - val_loss: 0.2550 - val_accuracy: 0.9455
# Epoch 12/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1615 - accuracy: 0.9639
# Epoch 12: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1615 - accuracy: 0.9616 - val_loss: 0.2389 - val_accuracy: 0.9636
# Epoch 13/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1824 - accuracy: 0.9375
# Epoch 13: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1882 - accuracy: 0.9313 - val_loss: 0.2210 - val_accuracy: 0.9636
# Epoch 14/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1573 - accuracy: 0.9591
# Epoch 14: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1603 - accuracy: 0.9556 - val_loss: 0.2239 - val_accuracy: 0.9455
# Epoch 15/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1714 - accuracy: 0.9471
# Epoch 15: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1674 - accuracy: 0.9535 - val_loss: 0.2155 - val_accuracy: 0.9636
# Epoch 16/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1344 - accuracy: 0.9712
# Epoch 16: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1333 - accuracy: 0.9697 - val_loss: 0.1927 - val_accuracy: 0.9455
# Epoch 17/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1401 - accuracy: 0.9567
# Epoch 17: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1452 - accuracy: 0.9556 - val_loss: 0.1776 - val_accuracy: 0.9636
# Epoch 18/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1343 - accuracy: 0.9663
# Epoch 18: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1355 - accuracy: 0.9636 - val_loss: 0.1879 - val_accuracy: 0.9455
# Epoch 19/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1528 - accuracy: 0.9567
# Epoch 19: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1603 - accuracy: 0.9495 - val_loss: 0.3038 - val_accuracy: 0.8545
# Epoch 20/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1415 - accuracy: 0.9447
# Epoch 20: val_accuracy did not improve from 0.96364
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1444 - accuracy: 0.9475 - val_loss: 0.1666 - val_accuracy: 0.9636
# [0.35691723227500916, 0.9636363387107849]
# Epoch 1/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.6893 - accuracy: 0.6899
# Epoch 1: val_accuracy improved from -inf to 0.41818, saving model to best_model.h5
# 16/16 [==============================] - 2s 27ms/step - loss: 0.6600 - accuracy: 0.7131 - val_loss: 1.0251 - val_accuracy: 0.4182
# Epoch 2/20
# 11/16 [===================>..........] - ETA: 0s - loss: 0.4151 - accuracy: 0.8636
# Epoch 2: val_accuracy improved from 0.41818 to 0.43636, saving model to best_model.h5
# 16/16 [==============================] - 0s 16ms/step - loss: 0.4284 - accuracy: 0.8606 - val_loss: 0.8935 - val_accuracy: 0.4364
# Epoch 3/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3522 - accuracy: 0.8798
# Epoch 3: val_accuracy improved from 0.43636 to 0.49091, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.3483 - accuracy: 0.8828 - val_loss: 0.8531 - val_accuracy: 0.4909
# Epoch 4/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3090 - accuracy: 0.9250
# Epoch 4: val_accuracy improved from 0.49091 to 0.72727, saving model to best_model.h5
# 16/16 [==============================] - 0s 19ms/step - loss: 0.3091 - accuracy: 0.9232 - val_loss: 0.5756 - val_accuracy: 0.7273
# Epoch 5/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.9152
# Epoch 5: val_accuracy did not improve from 0.72727
# 16/16 [==============================] - 0s 16ms/step - loss: 0.2819 - accuracy: 0.9152 - val_loss: 0.5336 - val_accuracy: 0.7273
# Epoch 6/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2655 - accuracy: 0.9250
# Epoch 6: val_accuracy improved from 0.72727 to 0.76364, saving model to best_model.h5
# 16/16 [==============================] - 0s 18ms/step - loss: 0.2638 - accuracy: 0.9253 - val_loss: 0.4935 - val_accuracy: 0.7636
# Epoch 7/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2415 - accuracy: 0.9313
# Epoch 7: val_accuracy improved from 0.76364 to 0.83636, saving model to best_model.h5
# 16/16 [==============================] - 0s 17ms/step - loss: 0.2415 - accuracy: 0.9313 - val_loss: 0.3961 - val_accuracy: 0.8364
# Epoch 8/20
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2120 - accuracy: 0.9442
# Epoch 8: val_accuracy did not improve from 0.83636
# 16/16 [==============================] - 0s 16ms/step - loss: 0.2046 - accuracy: 0.9495 - val_loss: 0.3651 - val_accuracy: 0.8182
# Epoch 9/20
# 16/16 [==============================] - ETA: 0s - loss: 0.1965 - accuracy: 0.9394
# Epoch 9: val_accuracy did not improve from 0.83636
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1965 - accuracy: 0.9394 - val_loss: 0.3357 - val_accuracy: 0.8364
# Epoch 10/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1766 - accuracy: 0.9542
# Epoch 10: val_accuracy improved from 0.83636 to 0.87273, saving model to best_model.h5
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1774 - accuracy: 0.9556 - val_loss: 0.3200 - val_accuracy: 0.8727
# Epoch 11/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1799 - accuracy: 0.9542
# Epoch 11: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1770 - accuracy: 0.9535 - val_loss: 0.3127 - val_accuracy: 0.8727
# Epoch 12/20
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1770 - accuracy: 0.9487
# Epoch 12: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1726 - accuracy: 0.9535 - val_loss: 0.3943 - val_accuracy: 0.7636
# Epoch 13/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1606 - accuracy: 0.9663
# Epoch 13: val_accuracy did not improve from 0.87273
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1636 - accuracy: 0.9616 - val_loss: 0.2863 - val_accuracy: 0.8727
# Epoch 14/20
# 11/16 [===================>..........] - ETA: 0s - loss: 0.1478 - accuracy: 0.9602
# Epoch 14: val_accuracy improved from 0.87273 to 0.89091, saving model to best_model.h5
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1472 - accuracy: 0.9596 - val_loss: 0.3216 - val_accuracy: 0.8909
# Epoch 15/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1428 - accuracy: 0.9479
# Epoch 15: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1405 - accuracy: 0.9495 - val_loss: 0.2797 - val_accuracy: 0.8727
# Epoch 16/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1277 - accuracy: 0.9729
# Epoch 16: val_accuracy did not improve from 0.89091
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1275 - accuracy: 0.9737 - val_loss: 0.4057 - val_accuracy: 0.7818
# Epoch 17/20
# 14/16 [=========================>....] - ETA: 0s - loss: 0.1118 - accuracy: 0.9888
# Epoch 17: val_accuracy improved from 0.89091 to 0.90909, saving model to best_model.h5
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1200 - accuracy: 0.9818 - val_loss: 0.3018 - val_accuracy: 0.9091
# Epoch 18/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1454 - accuracy: 0.9458
# Epoch 18: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1460 - accuracy: 0.9455 - val_loss: 0.5977 - val_accuracy: 0.8182
# Epoch 19/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1696 - accuracy: 0.9500
# Epoch 19: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1692 - accuracy: 0.9495 - val_loss: 0.4972 - val_accuracy: 0.9091
# Epoch 20/20
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1517 - accuracy: 0.9500
# Epoch 20: val_accuracy did not improve from 0.90909
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1489 - accuracy: 0.9515 - val_loss: 0.3444 - val_accuracy: 0.8727
# [0.30181318521499634, 0.9090909361839294]
# Epoch 1/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.6617 - accuracy: 0.7188
# Epoch 1: val_accuracy improved from -inf to 0.30909, saving model to best_model.h5
# 16/16 [==============================] - 2s 27ms/step - loss: 0.6392 - accuracy: 0.7293 - val_loss: 1.0618 - val_accuracy: 0.3091
# Epoch 2/20
# 13/16 [=======================>......] - ETA: 0s - loss: 0.4169 - accuracy: 0.8870
# Epoch 2: val_accuracy improved from 0.30909 to 0.36364, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4169 - accuracy: 0.8808 - val_loss: 1.0807 - val_accuracy: 0.3636
# Epoch 3/20
# 12/16 [=====================>........] - ETA: 0s - loss: 0.3491 - accuracy: 0.8958
# Epoch 3: val_accuracy improved from 0.36364 to 0.52727, saving model to best_model.h5
# ...
# Epoch 17/20
# 16/16 [==============================] - ETA: 0s - loss: 0.3203 - accuracy: 0.8869
# Epoch 17: val_accuracy improved from 0.61818 to 0.72727, saving model to best_model.h5
# 16/16 [==============================] - 4s 226ms/step - loss: 0.3203 - accuracy: 0.8869 - val_loss: 2.1436 - val_accuracy: 0.7273
# Epoch 18/20
# 16/16 [==============================] - ETA: 0s - loss: 0.3837 - accuracy: 0.8444
# Epoch 18: val_accuracy did not improve from 0.72727
# 16/16 [==============================] - 3s 204ms/step - loss: 0.3837 - accuracy: 0.8444 - val_loss: 3.1861 - val_accuracy: 0.4000
# Epoch 19/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2919 - accuracy: 0.8929
# Epoch 19: val_accuracy did not improve from 0.72727
# 16/16 [==============================] - 3s 207ms/step - loss: 0.2919 - accuracy: 0.8929 - val_loss: 2.0080 - val_accuracy: 0.5091
# Epoch 20/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2605 - accuracy: 0.8970
# Epoch 20: val_accuracy did not improve from 0.72727
# 16/16 [==============================] - 3s 208ms/step - loss: 0.2605 - accuracy: 0.8970 - val_loss: 2.3129 - val_accuracy: 0.4909
# [2.143622636795044, 0.7272727489471436]
# Epoch 1/20
# 16/16 [==============================] - ETA: 0s - loss: 1.1836 - accuracy: 0.5576
# Epoch 1: val_accuracy improved from -inf to 0.38182, saving model to best_model.h5
# 16/16 [==============================] - 7s 238ms/step - loss: 1.1836 - accuracy: 0.5576 - val_loss: 5.4231 - val_accuracy: 0.3818
# Epoch 2/20
# 16/16 [==============================] - ETA: 0s - loss: 0.7524 - accuracy: 0.6970
# Epoch 2: val_accuracy did not improve from 0.38182
# 16/16 [==============================] - 3s 207ms/step - loss: 0.7524 - accuracy: 0.6970 - val_loss: 3.3905 - val_accuracy: 0.3818
# Epoch 3/20
# 16/16 [==============================] - ETA: 0s - loss: 0.6654 - accuracy: 0.7313
# Epoch 3: val_accuracy did not improve from 0.38182
# 16/16 [==============================] - 3s 203ms/step - loss: 0.6654 - accuracy: 0.7313 - val_loss: 1.6952 - val_accuracy: 0.3818
# Epoch 4/20
# 16/16 [==============================] - ETA: 0s - loss: 0.5398 - accuracy: 0.7657
# Epoch 4: val_accuracy did not improve from 0.38182
# 16/16 [==============================] - 3s 203ms/step - loss: 0.5398 - accuracy: 0.7657 - val_loss: 5.1027 - val_accuracy: 0.3636
# Epoch 5/20
# 16/16 [==============================] - ETA: 0s - loss: 0.4933 - accuracy: 0.8141
# Epoch 5: val_accuracy did not improve from 0.38182
# 16/16 [==============================] - 3s 203ms/step - loss: 0.4933 - accuracy: 0.8141 - val_loss: 4.8151 - val_accuracy: 0.3636
# Epoch 6/20
# 16/16 [==============================] - ETA: 0s - loss: 0.4443 - accuracy: 0.8182
# Epoch 6: val_accuracy did not improve from 0.38182
# 16/16 [==============================] - 3s 206ms/step - loss: 0.4443 - accuracy: 0.8182 - val_loss: 8.4747 - val_accuracy: 0.3636
# Epoch 7/20
# 16/16 [==============================] - ETA: 0s - loss: 0.4579 - accuracy: 0.8020
# Epoch 7: val_accuracy did not improve from 0.38182
# 16/16 [==============================] - 3s 207ms/step - loss: 0.4579 - accuracy: 0.8020 - val_loss: 5.7319 - val_accuracy: 0.3636
# Epoch 8/20
# 16/16 [==============================] - ETA: 0s - loss: 0.3910 - accuracy: 0.8626
# Epoch 8: val_accuracy did not improve from 0.38182
# 16/16 [==============================] - 3s 208ms/step - loss: 0.3910 - accuracy: 0.8626 - val_loss: 1.9337 - val_accuracy: 0.3636
# Epoch 9/20
# 16/16 [==============================] - ETA: 0s - loss: 0.3725 - accuracy: 0.8545
# Epoch 9: val_accuracy improved from 0.38182 to 0.67273, saving model to best_model.h5
# 16/16 [==============================] - 4s 226ms/step - loss: 0.3725 - accuracy: 0.8545 - val_loss: 0.5797 - val_accuracy: 0.6727
# Epoch 10/20
# 16/16 [==============================] - ETA: 0s - loss: 0.3292 - accuracy: 0.8747
# Epoch 10: val_accuracy did not improve from 0.67273
# 16/16 [==============================] - 3s 214ms/step - loss: 0.3292 - accuracy: 0.8747 - val_loss: 3.5727 - val_accuracy: 0.3636
# Epoch 11/20
# 16/16 [==============================] - ETA: 0s - loss: 0.3200 - accuracy: 0.8727
# Epoch 11: val_accuracy did not improve from 0.67273
# 16/16 [==============================] - 3s 212ms/step - loss: 0.3200 - accuracy: 0.8727 - val_loss: 3.7910 - val_accuracy: 0.3636
# Epoch 12/20
# 16/16 [==============================] - ETA: 0s - loss: 0.3968 - accuracy: 0.8444
# Epoch 12: val_accuracy did not improve from 0.67273
# 16/16 [==============================] - 3s 208ms/step - loss: 0.3968 - accuracy: 0.8444 - val_loss: 2.3582 - val_accuracy: 0.4364
# Epoch 13/20
# 16/16 [==============================] - ETA: 0s - loss: 0.3484 - accuracy: 0.8646
# Epoch 13: val_accuracy did not improve from 0.67273
# 16/16 [==============================] - 3s 207ms/step - loss: 0.3484 - accuracy: 0.8646 - val_loss: 2.0707 - val_accuracy: 0.5818
# Epoch 14/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.8869
# Epoch 14: val_accuracy did not improve from 0.67273
# 16/16 [==============================] - 3s 207ms/step - loss: 0.2525 - accuracy: 0.8869 - val_loss: 1.2137 - val_accuracy: 0.6000
# Epoch 15/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2834 - accuracy: 0.8788
# Epoch 15: val_accuracy did not improve from 0.67273
# 16/16 [==============================] - 3s 210ms/step - loss: 0.2834 - accuracy: 0.8788 - val_loss: 1.0389 - val_accuracy: 0.5818
# Epoch 16/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9192
# Epoch 16: val_accuracy did not improve from 0.67273
# 16/16 [==============================] - 3s 209ms/step - loss: 0.2187 - accuracy: 0.9192 - val_loss: 5.3023 - val_accuracy: 0.3636
# Epoch 17/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2489 - accuracy: 0.8929
# Epoch 17: val_accuracy improved from 0.67273 to 0.76364, saving model to best_model.h5
# 16/16 [==============================] - 4s 224ms/step - loss: 0.2489 - accuracy: 0.8929 - val_loss: 0.4799 - val_accuracy: 0.7636
# Epoch 18/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2061 - accuracy: 0.9071
# Epoch 18: val_accuracy did not improve from 0.76364
# 16/16 [==============================] - 3s 204ms/step - loss: 0.2061 - accuracy: 0.9071 - val_loss: 2.1511 - val_accuracy: 0.5091
# Epoch 19/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2439 - accuracy: 0.9091
# Epoch 19: val_accuracy did not improve from 0.76364
# 16/16 [==============================] - 3s 208ms/step - loss: 0.2439 - accuracy: 0.9091 - val_loss: 1.9831 - val_accuracy: 0.5273
# Epoch 20/20
# 16/16 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9192
# Epoch 20: val_accuracy did not improve from 0.76364
# 16/16 [==============================] - 3s 203ms/step - loss: 0.2428 - accuracy: 0.9192 - val_loss: 2.8368 - val_accuracy: 0.4364
# [0.4799063801765442, 0.7636363506317139]
# Model: pose
# [1.7493505477905273, 0.6363636255264282]
# [0.49927157163619995, 0.8181818127632141]
# [7.304679870605469, 0.4727272689342499]
# [1.9170942306518555, 0.4545454680919647]
# [8.301475524902344, 0.6000000238418579]
# [8.788741111755371, 0.6000000238418579]
# [7.300559997558594, 0.6181818246841431]
# [3.605025053024292, 0.6909090876579285]
# [2.143622636795044, 0.7272727489471436]
# [0.4799063801765442, 0.7636363506317139]
# Best model was found to be: pose_classification_model_1
# 1/1 [==============================] - 1s 787ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# -------------------------------------------------------------------------
# pose evaluation on test set
# Macro F1 score: 0.6135976129582267
# Accuracy for each individual class:
# Class clear: 0.9137931034482759
# Class slice: 0.853448275862069
# Class smash: 0.8793103448275862
# Overall accuracy: 0.8103448275862069
# Mean Absolute Error: 0.1896551724137931
# Relative Error: 6.458032109076157
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-2de9a574bf1f> in <cell line: 5>()
#       5 for model_name, target_shape in zip(['audio', 'pose', 'comb'], [(128, 176), (62, 33, 4), (128, 308)]):
#       6   # for model_name, target_shape in zip(['pose'], [(62, 33, 4)]):
# ----> 7   model_file_name = train_model(model_name, target_shape, train_df, test_df)
#       8   X_train, X_test, y_train, y_test = get_model_input_data(train_df, test_df, model_name)
#       9   predictions = test_model(target_shape, model_file_name, X_test, y_test)
#
# <ipython-input-7-fba42d268800> in train_model(model_name, target_shape, train_df, test_df)
#      27       y_val_fold = y_train[val_indices_list[fold]]
#      28
# ---> 29       test_scores = create_fit_model(X_train_fold, y_train_fold, X_val_fold, y_val_fold, fold, model_name, target_shape)
#      30       scores.append(test_scores)
#      31
#
# <ipython-input-6-f889fa9bd3c4> in create_fit_model(X_train, y_train, X_val, y_val, index, model_name, target_shape)
#      74
#      75   # fit our model indicating epoch and batch_size
# ---> 76   model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_val, y_val), callbacks=[model_checkpoint_callback])
#      77
#      78   # After training, load the best model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     101       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102   ctx.ensure_initialized()
# --> 103   return ops.EagerTensor(value, ctx.device_name, dtype)
#     104
#     105
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type NoneType).
